# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("data_294.csv")

# %%
dataset
# Out:
#      Unnamed: 0   1  15  18    21       25       26        39       41  \
# 0             1  21  23   2  4565  19.2765   8.9368   64.0391  31.8953
# 1             2  23  23   2  5633  21.2244  10.3336   74.0391  36.5154
# 2             3  25  23   2  6789  23.1790  10.6986  101.5489  38.1809
# 3             4  19  23   2  4133  19.1405   8.8411   48.5293  28.3529
# 4             5  19  23   2  4133  19.8407   9.3362   48.5293  28.3529
# ..          ...  ..  ..  ..   ...      ...      ...       ...      ...
# 289         290  24  20   2  7140  24.4034  11.5737   71.8135  35.8413
# 290         291  26  20   2  8452  26.3662  11.9433  101.0586  43.6179
# 291         292  23  20   2  6531  23.4237  10.3809   81.7744  37.2985
# 292         293  25  20   2  7801  25.3843  11.7554   77.0195  44.4808
# 293         294  20  20   2  5430  23.0126  10.5810   53.5489  32.7359
#
#          58        69      83      85        141      155  166    Act
# ...

# %%
x = dataset.iloc [:, 1:16]

# %%
x
# Out:
#       1  15  18    21       25       26        39       41      58        69  \
# 0    21  23   2  4565  19.2765   8.9368   64.0391  31.8953  0.0154  200.4442
# 1    23  23   2  5633  21.2244  10.3336   74.0391  36.5154  0.0130  287.6204
# 2    25  23   2  6789  23.1790  10.6986  101.5489  38.1809  0.0134  257.3209
# 3    19  23   2  4133  19.1405   8.8411   48.5293  28.3529  0.0229  173.7359
# 4    19  23   2  4133  19.8407   9.3362   48.5293  28.3529  0.0229  168.7834
# ..   ..  ..  ..   ...      ...      ...       ...      ...     ...       ...
# 289  24  20   2  7140  24.4034  11.5737   71.8135  35.8413  0.0154  237.5433
# 290  26  20   2  8452  26.3662  11.9433  101.0586  43.6179  0.0134  312.0292
# 291  23  20   2  6531  23.4237  10.3809   81.7744  37.2985  0.0144  275.1655
# 292  25  20   2  7801  25.3843  11.7554   77.0195  44.4808  0.0131  330.3284
# 293  20  20   2  5430  23.0126  10.5810   53.5489  32.7359  0.0189  208.2390
#
#          83      85        141      155  166
# ...

# %%
y = dataset.loc [:, "Act"]

# %%
y
# Out:
# 0       1.58
# 1       1.93
# 2       2.65
# 3       1.46
# 4       2.95
#        ...
# 289     8.00
# 290     6.70
# 291    12.90
# 292     7.50
# 293     5.60
# Name: Act, Length: 294, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,test_size=.2, random_state = 7000)
# Out:
# [      1  15  18     21       25       26        39       41      58        69  \
#  124  52  42   6  30180  43.6681  21.3490  318.8510  52.6684  0.0154  688.2979
#  254  25  20   2   7732  25.5708  11.3874   89.3233  42.3979  0.0154  332.2677
#  214  23  18   2   2157  19.5851   6.8242   84.5035  36.4916  0.0143  280.7807
#  258  21  20   2   5640  22.7289  10.3813   60.7290  34.6206  0.0189  247.1030
#  56   28  27   2   7847  23.8737  10.7717   91.8136  40.7424  0.0144  279.7998
#  ..   ..  ..  ..    ...      ...      ...       ...      ...     ...       ...
#  263  35  20   2  14015  31.4458  14.6053  216.8073  49.6896  0.0144  522.4446
#  159  35  20   2  14029  31.4458  15.6574  208.6710  50.9524 -0.0919  460.3742
#  97   25  29   3   6340  20.5848   9.0484   90.2130  30.1199  0.0197  224.8629
#  233  26  20   2   9868  26.3662  11.9433  111.7486  41.8295  0.0134  320.1299
#  257  27  20   2   8690  26.0814  11.7434  113.7486  44.7111  0.0134  370.3459
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.2, random_state = 7000)

# %%
x_train.shape
# Out:
# (235, 15)

# %%
from sklearn.neural_network import MLPRegressor

# %%
#now we will state the network with the default setting 
nn = MLPRegressor ()

# %%
#Instantiate randomized search CV and fit to dataset

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
# creatting parameter gride
param_grid_nn= {'learning_rate': ['constant','adaptive','invscaling'], 'activation':['identity', 'logistic', 'tanh', 'relu'], 
    'solver': ['adm', 'sgd', 'lbfgs'], 'hidden_layer_sizes': [3,10,30]}

# %%
#Instantiate randomized search CV and fit to dataset
nn_random = RandomizedSearchCV(estimator =nn, param_distributions=param_grid_nn, n_iter = 10000,
                              cv = 5, verbose =2,
                              n_jobs= -1, scoring = "neg_mean_squared_error" )

# %%
nn_random.fit (x,y)
# Out:
# C:\Python39\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 108 is smaller than n_iter=10000. Running 108 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# C:\Python39\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [            nan             nan -1.83991975e+03             nan
#              nan -1.74024753e+03             nan             nan
#  -1.73486686e+03             nan             nan -1.72872771e+03
#              nan             nan -1.86311477e+03             nan
#              nan -1.66537396e+03             nan             nan
#  -1.85260575e+03             nan             nan -1.67089868e+03
#              nan             nan -1.75978912e+03             nan
#  -3.03183502e+03 -3.07031363e+03             nan -3.26671785e+03
# ...

# %%
nn_random.best_params_
# Out:
# {'solver': 'lbfgs',
#  'learning_rate': 'invscaling',
#  'hidden_layer_sizes': 10,
#  'activation': 'identity'}

# %%
nn_grid = GridSearchCV(estimator =nn, param_grid=param_grid_nn,
                              cv = 5, verbose =2,
                              n_jobs= -1, scoring = "neg_mean_squared_error" )

nn_grid.fit (x,y)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# C:\Python39\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [            nan             nan -1.68192842e+03             nan
#              nan -1.70314483e+03             nan             nan
#  -1.63856710e+03             nan             nan -1.83297133e+03
#              nan             nan -1.65170633e+03             nan
#              nan -1.80014540e+03             nan             nan
#  -1.81245272e+03             nan             nan -1.81366120e+03
#              nan             nan -1.76485820e+03             nan
#  -3.23251078e+03 -3.00038739e+03             nan -2.94193373e+03
#  -3.05421199e+03             nan -3.73322894e+03 -3.05421202e+03
#              nan -3.01751412e+03 -2.92820187e+03             nan
#  -3.05002293e+03 -2.88369443e+03             nan -3.49845703e+03
#  -2.83660746e+03             nan -2.90771992e+03 -3.18872334e+03
# ...

# %%
nn_grid.best_params_
# Out:
# {'activation': 'identity',
#  'hidden_layer_sizes': 3,
#  'learning_rate': 'invscaling',
#  'solver': 'lbfgs'}

# %%
from sklearn.model_selection import cross_val_score

# %%
grid = []
for i in range(20):
    grid.append(-cross_val_score (MLPRegressor(learning_rate = "invscaling", activation = "identity",
                                                  solver ="sgd", hidden_layer_sizes = 20),
                                x,y.ravel(), cv =5, scoring = "neg_mean_squared_error").mean())
# Out:
# C:\Python39\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Python39\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Python39\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Python39\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
# ...

# %%
y_predict = nn.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-30-483503beda45> in <module>
# ----> 1 y_predict = nn.predict(x_test)
#
# C:\Python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in predict(self, X)
#    1405             The predicted values.
#    1406         """
# -> 1407         check_is_fitted(self)
#    1408         y_pred = self._forward_pass_fast(X)
#    1409         if y_pred.shape[1] == 1:
#
# C:\Python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\Python39\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
# ...

# %%
y_predict

# %%
from sklearn import metrics

# %%
mse=metrics.mean_squared_error (y_predict, y_test)

# %%
print (mse)

# %%
NNTT.append("mse")

# %%
from matplotlib import pyplot as plt

# %%
plt.plot (mse,'-b', label = "NN")
plt.plot ('loc = "best"')
plt.ylabel ("Test mean squere error")
plt.xlabel ("Itresion number")

# %%
NNTT = []
for i in range (10):
    train_test_split(x,y,test_size=.2,random_state=4)
